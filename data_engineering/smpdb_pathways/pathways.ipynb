# %% [markdown]
# # Read all data from SMPDB pathway database
#
# The data remains unused because there are too much pathways to use them as a feature

# %%
import pandas as pd
import numpy as np
import data_utils as du
import scipy.sparse as sparse
data_dir = du.find_data_dir('app')
pathways_file = du.get_file_path(data_dir, 'SMPDB pathways', 'unprocessed', 'smpdb_pathways.csv')
df = pd.read_csv(pathways_file).set_index('SMPDB ID')

# %%
df
# Out:
#                PW ID                                               Name  \
# SMPDB ID
# SMP0000055  PW000001                                 Alanine Metabolism
# SMP0000067  PW000002                               Aspartate Metabolism
# SMP0000072  PW000003                               Glutamate Metabolism
# SMP0000015  PW000004                             Glutathione Metabolism
# SMP0000057  PW000005                                  Citric Acid Cycle
# ...              ...                                                ...
# SMP0121060  PW122328  Kandutsch-Russell Pathway (Cholesterol Biosynt...
# SMP0121123  PW122396                            Arsenate Detoxification
# SMP0121126  PW122401                  Aldosterone from Steroidogenesis
# SMP0121128  PW122406                     Pancreas Function - Delta Cell
# SMP0121131  PW122411  2-Amino-3-carboxymuconate semialdehyde Degrada...
#
#                   Subject                                        Description
# SMPDB ID
# ...
